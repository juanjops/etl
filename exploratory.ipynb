# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %%
data_frame = (pd.read_csv("C:\\Users\\Sectorea\\Code\\database_linkedin\\text_analyze_data_scientist_London_Past_Week_2020-04-12.csv"))
data_frame.shape
# Out:
# (973, 12)

# %%
data_frame.head()
# Out:
#            id                                   title              company  \
# 0  1823300155                          Data Scientist             Vitality
# 1  1822785444                          Data Scientist           CharityJob
# 2  1823069656              Data Scientist Consultancy  Metrica Recruitment
# 3  1823422195  Product Data Scientist- Remote Working    Retail Jobs Store
# 4  1823078780               Data Scientist on England              Beamery
#
#                           location    posted  applicants          level  \
# 0  London, England, United Kingdom  0.500000           0   Entry level
# 1  London, England, United Kingdom  0.833333           0   Entry level
# 2  London, England, United Kingdom  0.750000           0   Entry level
# 3  London, England, United Kingdom  0.416667           0   Entry level
# 4  London, England, United Kingdom  0.750000           0   Entry level
#
#           type                             functions  \
# 0   Full-time    Engineering Information Technology
# 1   Temporary    Engineering Information Technology
# 2   Full-time    Engineering Information Technology
# 3   Full-time    Engineering Information Technology
# 4   Full-time    Engineering Information Technology
#
#                                           industries  \
# 0   Marketing and Advertising Insurance Financial...
# 1   Philanthropy Nonprofit Organization Managemen...
# 2   Information Technology and Services Staffing ...
# 3   Information Technology and Services Staffing ...
# 4   Information Technology and Services Computer ...
#
#                               key_words  \
# 0                   python r sql mining
# 1  python r qlik tableau sql hadoop etl
# 2              python r sql cloud azure
# 3                    python tableau sql
# 4        python r sql java cloud mining
#
#                                     misspelled_words
# 0          visualizations ’ ukwe up-sell analytics £
# 1  you're alteryx po6 council's po7about analytic...
# 2                                          analytics
# 3                 c-suite £ analytics visualisations
# 4            modeling stata analytics matlab beamery

# %%
def get (feature): 
    variable_extension = " ".join(review for review in feature if type(review) is not float)
    wordcloud = WordCloud(
        max_font_size=50, max_words=100, background_color="white",collocations=False,
        prefer_horizontal=1).generate(variable_extension)
    variable_count = variable_extension.split(" ")
    print(Counter(variable_count).most_common(100))
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
get(data_frame.key_words)
# Out:
# [('python', 640), ('sql', 487), ('analytics', 482), ('r', 358), ('cloud', 182), ('tableau', 173), ('aws', 144), ('spark', 135), ('agile', 130), ('mining', 103), ('dashboards', 101), ('hadoop', 97), ('java', 89), ('azure', 76), ('etl', 76), ('tensorflow', 68), ('scala', 56), ('gcp', 51), ('visualisations', 48), ('hive', 48), ('keras', 47), ('kpis', 34), ('startups', 28), ('qlik', 26), ('kafka', 25), ('docker', 24), ('apis', 24), ('crm', 24), ('kubernetes', 19), ('mongo', 17), ('scrum', 16), ('neo', 10), ('kpi', 10), ('sklearn', 8), ('b2b', 8), ('b2c', 5), ('cloudera', 5), ('impala', 3), ('sqoop', 1)]

# %%
get(data_frame.title)
# Out:
# [('Data', 950), ('Scientist', 454), ('Analyst', 316), ('-', 260), ('Senior', 122), ('Science', 93), ('Big', 46), ('Lead', 45), ('Engineer', 41), ('London', 40), ('Learning', 31), ('/', 30), ('Junior', 30), ('Machine', 28), ('of', 26), ('Business', 25), ('&', 24), ('Graduate', 24), ('Head', 22), ('Consultant', 21), ('Analytics', 20), ('Scientist,', 20), ('Developer', 19), ('Research', 16), ('|', 16), ('and', 14), ('Python', 13), ('on', 13), ('England', 12), ('Intelligence', 11), ('or', 11), ('Remote', 10), ('Product', 10), ('Analyst,', 10), ('–', 10), ('BI', 9), ('65k', 9), ('Principal', 9), ('000', 9), ('NLP', 8), ('Experience', 8), ('AI', 8), ('+', 8), ('Consultancy', 8), ('UK', 8), ('month', 7), ('SQL', 7), ('InsurTech', 7), ('to', 6), ('Contract', 6), ('Financial', 6), ('Client', 6), ('Digital', 6), ('Specialist', 6), ('Lecturer', 6), ('Intern', 6), ('Game', 6), ('FTC)', 5), ('Associate', 5), ('Interview', 5), ('DATA', 5), ('Engineering', 5), ('Reporting', 5), ('Market', 5), ('AWS', 5), ('Customer', 5), ('Manager', 5), ('Services', 5), ('Causality', 5), ('Expert', 5), ('Artificial', 5), ('Statistician', 5), ('2020', 4), ('Decision', 4), ('Bank', 4), ('Looker', 4), ('Marketing', 4), ('ANALYST', 4), ('Tableau', 4), ('Global', 4), ('Technical', 4), ('Manager,', 4), ('R', 4), ('Science)', 4), ('Cloud', 4), ('Credit', 4), ('Role', 4), ('', 4), ('Based', 4), ('in', 4), ('Dhahran,', 4), ('SA', 4), ('Applied', 4), ('Investment', 4), ('Director', 4), ('£80-110k', 4), ('Management', 4), ('(9', 3), ('for', 3), ('R&', 3)]

# %%
get(data_frame.functions)
# Out:
# [('', 1940), ('Information', 765), ('Technology', 765), ('Engineering', 392), ('Other', 133), ('Analyst', 71), ('Consulting', 27), ('Research', 25), ('Finance', 20), ('Strategy/Planning', 18), ('Management', 18), ('Science', 16), ('Sales', 15), ('Business', 12), ('Project', 10), ('Development', 9), ('Marketing', 8), ('Legal', 7), ('Product', 6), ('General', 3), ('Education', 3), ('Training', 3), ('Human', 2), ('Resources', 2), ('Design', 2), ('Customer', 2), ('Service', 2), ('Advertising', 2), ('Production', 1), ('Art/Creative', 1), ('Public', 1), ('Relations', 1), ('Writing/Editing', 1)]

# %%
get(data_frame.industries)
# Out:
# [('and', 1002), ('', 970), ('Services', 913), ('Information', 535), ('Technology', 527), ('Computer', 507), ('Software', 469), ('Financial', 365), ('Staffing', 258), ('Recruiting', 258), ('Internet', 243), ('Marketing', 212), ('Advertising', 212), ('Management', 82), ('&', 64), ('Insurance', 62), ('Consulting', 48), ('Human', 36), ('Resources', 36), ('Banking', 33), ('Research', 31), ('Media', 29), ('Education', 24), ('Online', 24), ('Construction', 21), ('Hospital', 17), ('Health', 17), ('Care', 17), ('Games', 17), ('Retail', 17), ('Organization', 17), ('Pharmaceuticals', 16), ('Nonprofit', 16), ('Telecommunications', 14), ('Network', 14), ('Security', 14), ('Biotechnology', 13), ('Food', 13), ('Consumer', 12), ('Entertainment', 10), ('Electrical/Electronic', 10), ('Manufacturing', 10), ('Investment', 10), ('Oil', 9), ('Energy', 9), ('Engineering', 8), ('Publishing', 8), ('Higher', 8), ('Accounting', 7), ('Beverages', 7), ('Government', 7), ('Administration', 7), ('Production', 7), ('Legal', 6), ('Design', 6), ('Real', 6), ('Estate', 6), ('Renewables', 6), ('Environment', 6), ('Sports', 5), ('Market', 5), ('Automotive', 5), ('Networking', 5), ('Mechanical', 4), ('or', 4), ('Industrial', 4), ('Civil', 4), ('Philanthropy', 4), ('Fund-Raising', 4), ('Broadcast', 4), ('Capital', 4), ('Markets', 4), ('Professional', 4), ('Training', 4), ('Coaching', 4), ('Medical', 4), ('Utilities', 3), ('Goods', 3), ('Logistics', 3), ('Supply', 3), ('Chain', 3), ('Gambling', 3), ('Casinos', 3), ('Devices', 3), ('Transportation/Trucking/Railroad', 3), ('Newspapers', 2), ('Primary/Secondary', 2), ('Leisure,', 2), ('Travel', 2), ('Tourism', 2), ('Hospitality', 2), ('Electronics', 2), ('Commercial', 2), ('Hardware', 2), ('Machinery', 1), ('Music', 1), ('Public', 1), ('Relations', 1), ('Communications', 1), ('Civic', 1)]

# %%
get(data_frame.misspelled_words)
# Out:
# [('’', 447), ('£', 240), ('–', 206), ("you'll", 109), ('www', 91), ('google', 90), ("we're", 88), ('py', 86), ('scikit', 82), ('mentoring', 69), ('‘', 57), ('https', 54), ('website', 53), ('…', 51), ("you're", 49), ('modeling', 45), ('”', 45), ('“', 43), ('numpy', 43), ('matlab', 41), ('jupyter', 37), ('impactful', 37), ('deliverables', 32), ("it's", 30), ('annum', 30), ("world's", 25), ("uk's", 24), ("master's", 24), ('linux', 24), ('vba', 24), ('cto', 23), ('facebook', 20), ('alteryx', 20), ('workflows', 19), ('scoping', 19), ('deliveroo', 19), ("company's", 18), ('certifications', 18), ('fintech', 18), ('linkedin', 18), ('websites', 18), ('™', 17), ("we've", 17), ("europe's", 17), ('covid', 17), ('matplotlib', 17), ("what's", 17), ('deeptech', 17), ('recommender', 16), ('ecommerce', 16), ("client's", 16), ('3rd', 16), ('@xcede', 16), ('65k', 15), ('stata', 15), ('0)203', 15), ('roadmaps', 15), ('upload', 15), ('postgres', 15), ("bachelor's", 15), ('productionise', 15), ('databricks', 14), ('—', 14), ("we'd", 14), ("we'll", 14), ('pytorch', 13), ('301', 13), ('visualizations', 13), ('ggplot', 12), ('svm', 12), ('postgre', 12), ('iterating', 12), ('rsquo', 12), ('5mb', 12), ('docx', 12), ('mllib', 12), ('0191', 11), ("isn't", 11), ('skyrocketing', 11), ('hotwire', 11), ("xcede's", 11), ('4j', 10), ('bioinformatics', 10), ('carthy', 10), ('plotly', 10), ('@jeffersonfrank', 10), ('gdpr', 10), ('seo', 10), ('scipy', 10), ('isn', 10), ('emr', 10), ('ssis', 10), ('newswire', 10), ('theano', 10), ('sagemaker', 10), ('0203', 9), ('productiveness', 9), ("they've", 9), ('backend', 9), ('debug', 9)]
