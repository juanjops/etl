# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %%
data_frame = (pd.read_csv("C:\\Users\\Sectorea\\Code\\database_linkedin\\text_analyzed\\text_analyze_data_science_Madrid_Any_Time_2020-04-13.csv"))
data_frame.shape
# Out:
# (422, 12)

# %%
data_frame.head()
# Out:
#            id                                              title  \
# 0  1776499375                      Data Scientist (H/M) - Madrid
# 1  1820247263  Business Development Representative - English/...
# 2  1812956713                       System Administrator - Linux
# 3  1709927470                    Test Manager (SEL Verification)
# 4  1581663854          Customer Service. German or Dutch Speaker
#
#              company                                           location  \
# 0  IT Partner España  San Sebastián de los Reyes, Community of Madri...
# 1  Amazonwebservices  San Sebastián de los Reyes, Community of Madri...
# 2            Ekkiden  San Sebastián de los Reyes, Community of Madri...
# 3    Damco Solutions  San Sebastián de los Reyes, Community of Madri...
# 4     Page Personnel  San Sebastián de los Reyes, Community of Madri...
#
#    posted  applicants               level         type  \
# 0    30.0           0        Entry level    Full-time
# 1     6.0           0        Entry level    Full-time
# 2    14.0           0          Associate    Full-time
# 3    90.0           0   Mid-Senior level    Full-time
# 4   180.0           0        Entry level    Full-time
#
#                                    functions  \
# 0        Engineering Information Technology
# 1                Sales Business Development
# 2                    Information Technology
# 3                         Quality Assurance
# 4   Customer Service Information Technology
#
#                                           industries  \
# 0   Information Technology and Services Computer ...
# 1   Information Technology and Services Computer ...
# 2   Information Technology and Services Computer ...
# 3   Information Technology and Services Computer ...
# 4   Electrical/Electronic Manufacturing Machinery...
#
#                       key_words  \
# 0    python r scala spark azure
# 1  aws cloud analytics startups
# 2          python sql aws cloud
# 3                           NaN
# 4                           NaN
#
#                                     misspelled_words
# 0  valorable desempeñando analíticas còdigo v2 mo...
# 1     bdr internships customer's cxo mentorship emea
# 2  ’ it's responsabilities 80tb ekkiden bitbucket...
# 3  208 068 1757 damco versioning damcosoft sudhee...
# 4  telemarketer inmediate verificación emisión wh...

# %%
def get (feature): 
    variable_extension = " ".join(review for review in feature if type(review) is not float)
    wordcloud = WordCloud(
        max_font_size=50, max_words=100, background_color="white",collocations=False,
        prefer_horizontal=1).generate(variable_extension)
    variable_count = variable_extension.split(" ")
    print(Counter(variable_count).most_common(100))
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
get(data_frame.key_words)
# Out:
# [('python', 178), ('analytics', 157), ('sql', 136), ('java', 126), ('r', 105), ('aws', 99), ('cloud', 95), ('agile', 95), ('spark', 61), ('apis', 53), ('hadoop', 38), ('scrum', 37), ('azure', 32), ('tableau', 32), ('mining', 29), ('gcp', 28), ('scala', 26), ('b2b', 23), ('dashboards', 22), ('hive', 22), ('etl', 21), ('b2c', 21), ('docker', 20), ('kpi', 19), ('tensorflow', 17), ('kubernetes', 17), ('startups', 16), ('keras', 16), ('mongo', 14), ('neo', 12), ('crm', 10), ('kafka', 9), ('kpis', 8), ('qlik', 7), ('sklearn', 6), ('impala', 5), ('cloudera', 2)]

# %%
get(data_frame.title)
# Out:
# [('Data', 950), ('Scientist', 454), ('Analyst', 316), ('-', 260), ('Senior', 122), ('Science', 93), ('Big', 46), ('Lead', 45), ('Engineer', 41), ('London', 40), ('Learning', 31), ('/', 30), ('Junior', 30), ('Machine', 28), ('of', 26), ('Business', 25), ('&', 24), ('Graduate', 24), ('Head', 22), ('Consultant', 21), ('Analytics', 20), ('Scientist,', 20), ('Developer', 19), ('Research', 16), ('|', 16), ('and', 14), ('Python', 13), ('on', 13), ('England', 12), ('Intelligence', 11), ('or', 11), ('Remote', 10), ('Product', 10), ('Analyst,', 10), ('–', 10), ('BI', 9), ('65k', 9), ('Principal', 9), ('000', 9), ('NLP', 8), ('Experience', 8), ('AI', 8), ('+', 8), ('Consultancy', 8), ('UK', 8), ('month', 7), ('SQL', 7), ('InsurTech', 7), ('to', 6), ('Contract', 6), ('Financial', 6), ('Client', 6), ('Digital', 6), ('Specialist', 6), ('Lecturer', 6), ('Intern', 6), ('Game', 6), ('FTC)', 5), ('Associate', 5), ('Interview', 5), ('DATA', 5), ('Engineering', 5), ('Reporting', 5), ('Market', 5), ('AWS', 5), ('Customer', 5), ('Manager', 5), ('Services', 5), ('Causality', 5), ('Expert', 5), ('Artificial', 5), ('Statistician', 5), ('2020', 4), ('Decision', 4), ('Bank', 4), ('Looker', 4), ('Marketing', 4), ('ANALYST', 4), ('Tableau', 4), ('Global', 4), ('Technical', 4), ('Manager,', 4), ('R', 4), ('Science)', 4), ('Cloud', 4), ('Credit', 4), ('Role', 4), ('', 4), ('Based', 4), ('in', 4), ('Dhahran,', 4), ('SA', 4), ('Applied', 4), ('Investment', 4), ('Director', 4), ('£80-110k', 4), ('Management', 4), ('(9', 3), ('for', 3), ('R&', 3)]

# %%
get(data_frame.functions)
# Out:
# [('', 1940), ('Information', 765), ('Technology', 765), ('Engineering', 392), ('Other', 133), ('Analyst', 71), ('Consulting', 27), ('Research', 25), ('Finance', 20), ('Strategy/Planning', 18), ('Management', 18), ('Science', 16), ('Sales', 15), ('Business', 12), ('Project', 10), ('Development', 9), ('Marketing', 8), ('Legal', 7), ('Product', 6), ('General', 3), ('Education', 3), ('Training', 3), ('Human', 2), ('Resources', 2), ('Design', 2), ('Customer', 2), ('Service', 2), ('Advertising', 2), ('Production', 1), ('Art/Creative', 1), ('Public', 1), ('Relations', 1), ('Writing/Editing', 1)]

# %%
get(data_frame.industries)
# Out:
# [('and', 1002), ('', 970), ('Services', 913), ('Information', 535), ('Technology', 527), ('Computer', 507), ('Software', 469), ('Financial', 365), ('Staffing', 258), ('Recruiting', 258), ('Internet', 243), ('Marketing', 212), ('Advertising', 212), ('Management', 82), ('&', 64), ('Insurance', 62), ('Consulting', 48), ('Human', 36), ('Resources', 36), ('Banking', 33), ('Research', 31), ('Media', 29), ('Education', 24), ('Online', 24), ('Construction', 21), ('Hospital', 17), ('Health', 17), ('Care', 17), ('Games', 17), ('Retail', 17), ('Organization', 17), ('Pharmaceuticals', 16), ('Nonprofit', 16), ('Telecommunications', 14), ('Network', 14), ('Security', 14), ('Biotechnology', 13), ('Food', 13), ('Consumer', 12), ('Entertainment', 10), ('Electrical/Electronic', 10), ('Manufacturing', 10), ('Investment', 10), ('Oil', 9), ('Energy', 9), ('Engineering', 8), ('Publishing', 8), ('Higher', 8), ('Accounting', 7), ('Beverages', 7), ('Government', 7), ('Administration', 7), ('Production', 7), ('Legal', 6), ('Design', 6), ('Real', 6), ('Estate', 6), ('Renewables', 6), ('Environment', 6), ('Sports', 5), ('Market', 5), ('Automotive', 5), ('Networking', 5), ('Mechanical', 4), ('or', 4), ('Industrial', 4), ('Civil', 4), ('Philanthropy', 4), ('Fund-Raising', 4), ('Broadcast', 4), ('Capital', 4), ('Markets', 4), ('Professional', 4), ('Training', 4), ('Coaching', 4), ('Medical', 4), ('Utilities', 3), ('Goods', 3), ('Logistics', 3), ('Supply', 3), ('Chain', 3), ('Gambling', 3), ('Casinos', 3), ('Devices', 3), ('Transportation/Trucking/Railroad', 3), ('Newspapers', 2), ('Primary/Secondary', 2), ('Leisure,', 2), ('Travel', 2), ('Tourism', 2), ('Hospitality', 2), ('Electronics', 2), ('Commercial', 2), ('Hardware', 2), ('Machinery', 1), ('Music', 1), ('Public', 1), ('Relations', 1), ('Communications', 1), ('Civic', 1)]

# %%
get(data_frame.misspelled_words)
# Out:
# [('’', 179), ('–', 79), ('“', 47), ("bachelor's", 46), ('…', 45), ('”', 45), ('™', 37), ('learning', 34), ('www', 33), ('json', 32), ('linux', 30), ('quintiles', 30), ('iqvia', 30), ('´', 29), ('scientist', 28), ('html', 28), ('modeling', 26), ("master's", 26), ('kotlin', 24), ('cto', 24), ("we're", 23), ('mvc', 23), ('css', 22), ('backends', 22), ('emea', 21), ('‘', 21), ('mentoring', 21), ('predictivos', 21), ('tdd', 20), ('microservices', 20), ("world's", 19), ('valorará', 19), ('monetization', 19), ('valorable', 18), ('downloads', 18), ('mvvm', 18), ('multiplatform', 18), ('\x92', 18), ('frontends', 18), ('mvp', 18), ('150k', 18), ('xml', 17), ('bitbucket', 16), ('ingenierías', 16), ('analyst', 16), ('jira', 15), ('—', 15), ('https', 15), ('google', 15), ('bise', 15), ('retributivo', 15), ('py', 15), ('¡', 14), ('matlab', 13), ('rwe', 13), ("you'll", 13), ('javascript', 13), ('serverless', 13), ('apply', 12), ('tareas', 12), ('perfil', 12), ("customer's", 11), ('visualizations', 11), ('devops', 11), ('timelines', 11), ('empleo', 11), ('ecai', 11), ('emnlp', 11), ('aaai', 11), ('ijcai', 11), ('internships', 10), ('relacionales', 10), ('perseverant', 10), ("amazon's", 10), ('linkedin', 10), ('numpy', 10), ('4j', 10), ('descripción', 10), ('eeo', 10), ('ux', 10), ('backend', 10), ('deliverables', 10), ('scoping', 10), ('databricks', 9), ('cro', 9), ('integrations', 9), ('pharm', 9), ('optimización', 9), ('sde', 9), ('accenture', 9), ('5g', 9), ('onboarding', 9), ('teletrabajo', 9), ('certifications', 9), ('bbdd', 8), ("you're", 8), ("that's", 8), ('skillfully', 8), ('happener', 8), ('romainville', 8)]
