# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %%
data_frame = pd.read_csv("text_analyzed_data_scientist_Madrid_Past_Month_2020-04-11.csv")
data_frame.shape
# Out:
# (275, 12)

# %%
data_frame.head()
# Out:
#            id                                title             company  \
# 0  1810055462              Data Science R y Python          Gfi España
# 1  1794127974                  Python Data Analyst            Aplazame
# 2  1757831422  Data Scientist - Advanced Analytics  McKinsey & Company
# 3  1713962733     Data Scientist & Project Manager                CHEP
# 4  1819396078                       Data Scientist       SlashMobility
#
#                                             location posted  applicants  \
# 0                 Madrid, Community of Madrid, Spain    5.0         184
# 1                 Madrid, Community of Madrid, Spain    3.0         179
# 2  San Sebastián de los Reyes, Community of Madri...   28.0         161
# 3                 Madrid, Community of Madrid, Spain   21.0           0
# 4  San Sebastián de los Reyes, Community of Madri...    3.0           0
#
#                 level         type  \
# 0   Mid-Senior level    Full-time
# 1          Associate    Full-time
# 2        Entry level    Full-time
# 3          Associate    Full-time
# 4        Entry level    Full-time
#
#                                          functions  \
# 0               Consulting Information Technology
# 1                             Analyst Engineering
# 2   Consulting Engineering Information Technology
# 3     Supply Chain Information Technology Science
# 4              Engineering Information Technology
#
#                                           industries  \
# 0                Information Technology and Services
# 1                                 Financial Services
# 2   Computer Software Information Technology and ...
# 3   Logistics and Supply Chain Consumer Goods Inf...
# 4   Information Technology and Services Computer ...
#
#                                            key_words  \
# 0                                                  r
# 1                             python tableau sql etl
# 2                   python r spark sql hadoop mining
# 3        python r tableau sql hadoop aws java mining
# 4  python scala spark hive aws java cloud azure k...
#
#                                     misspelled_words
# 0  gfi distribuirlos aportada-plan teletrabajo an...
# 1  postgres redshift inscríbete definirás analíti...
# 2                awk you'll ´ ’ – analytics modeling
# 3  1-3 dashboards ’ efficienty stadistic spak ana...
# 4  learning similiar predictivos mllib xgboost co...

# %%
key_words = " ".join(review for review in data_frame.key_words if type(review) is not float)
wordcloud = WordCloud(
    max_font_size=50, max_words=100, background_color="white",collocations=False,
    prefer_horizontal=1).generate(key_words)
key_words_count = key_words.split(" ")

# %%
print(Counter(key_words_count).most_common(10))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [('python', 100), ('sql', 99), ('hadoop', 99), ('spark', 89), ('hive', 88), ('r', 68), ('agile', 65), ('impala', 56), ('cloud', 55), ('cloudera', 46)]
