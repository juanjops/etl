# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
interest_rates = pd.read_csv("C:\\Users\\Sectorea\\Downloads\\fed-funds-rate-historical-chart.csv", skiprows=15, index_col="date")
interest_rates.index = pd.to_datetime(interest_rates.index)
interest_rates = interest_rates.rename(columns={" value": "rates"})
interest_rates = interest_rates.resample("1Y").mean()
interest_rates.index = interest_rates.index.year
interest_rates.head()
# Out:
#          rates
# date
# 1954  1.008424
# 1955  1.788603
# 1956  2.729590
# 1957  3.105342
# 1958  1.572356

# %%
inflation = [1.81, 2.44, 2.13, 1.26, 0.12, 1.62, 1.47, 2.07, 3.16, 1.64, -0.34, 3.85, 2.85, 3.24, 3.39, 2.68, 2.27, 1.59, 2.83, 3.38, 2.19, 1.55, 2.34, 2.93, 2.81, 2.61, 2.96, 3.03, 4.25, 5.39, 4.83, 4.08, 3.66, 1.91, 3.55, 4.3, 3.22, 6.16, 10.35, 13.58, 11.22, 7.62, 6.5, 5.75, 9.2, 11.03, 6.16, 3.27, 4.3, 5.84, 5.46, 4.27, 2.78, 3.01, 1.59, 1.28, 1.24, 1.2, 1.07, 1.46, 1.01, 2.73, 3.34, 1.52, -0.28, 0.32, 0.82, 2.29, 7.88, 1.09, -0.95, 7.74, 14.65, 8.43, 2.27, 1.64, 6.0, 10.97, 5.11, 0.73, -1.3, -2.01, 3.73, 1.04, 2.56, 3.51, -5.09, -10.3, -8.94, -2.66, 0.0, -1.15, -1.92, 0.94, 2.44, 0.45, 1.8, -6.1, -10.85, 15.9, 15.31, 17.26, 17.8, 7.64, 0.92, 1.35]
years = [2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953, 1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943, 1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921, 1920, 1919, 1918, 1917, 1916, 1915, 1914]

# %%
inflation = pd.DataFrame({"inflation": inflation}, index=years)

# %%
dataframe = interest_rates.merge(inflation, left_index=True, right_index=True)

# %%
dataframe[10:60].plot(y=["rates", "inflation"], use_index=True, figsize=(15,5), grid=True)

# %%
dataframe_diff = dataframe.pct_change()

# %%
dataframe_diff[10:40].plot(y=["rates", "inflation"], use_index=True, figsize=(15,5))
plt.axhline(y=0, color='r', linestyle='-')
